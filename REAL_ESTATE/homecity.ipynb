# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
from lxml import etree
import re

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0',
    "Accept-Encoding": "*",
    "Connection": "keep-alive"
    }

# %%
main_url = 'https://homecityaruba.com/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0',
    "Accept-Encoding": "*",
    "Connection": "keep-alive"
    }
hyper = ['https://homecityaruba.com/for-sale',
         'https://homecityaruba.com/for-rent'
    ]

# %%
def get_all_url(li):
    all_links = []
    for url in li:
        req = requests.get(url)
        soup = BeautifulSoup(req.content, "html.parser")
        anchors = soup.find('div', {'class': 'preview-properties'})
        links  = anchors.find_all('a', href = True)
        for link in links:
            urls = main_url + link.get('href')
            
            #print(urls)
            all_links.append(urls)
    return all_links
path = get_all_url(hyper)

# %%
path2 = []
 
for i in path:
    if i not in path2:
        path2.append(i)

# %%
path2
# Out:
# ['https://homecityaruba.com//listings/land-bubali-3',
#  'https://homecityaruba.com//listings/noord-392-m2',
#  'https://homecityaruba.com//listings/modanza-470-m2',
#  'https://homecityaruba.com//listings/land-bubali-solarium-lot-8',
#  'https://homecityaruba.com//listings/land-bubali-solarium-lot-7',
#  'https://homecityaruba.com//listings/sabana-blanco-lot-4-1203m2',
#  'https://homecityaruba.com//listings/sabana-blanco-lot-3-1203m2',
#  'https://homecityaruba.com//listings/home-tazajal',
#  'https://homecityaruba.com//listings/seroe-blanco-438-m2',
#  'https://homecityaruba.com//listings/house-sta-cruz',
#  'https://homecityaruba.com//listings/cozy-sabana-basora',
#  'https://homecityaruba.com//listings/tazajal-15',
#  'https://homecityaruba.com//listings/land-bubali-solarium-residence-11',
#  'https://homecityaruba.com//listings/home-pos-chiquito',
#  'https://homecityaruba.com//listings/apartment-oranjestad-2',
#  'https://homecityaruba.com//listings/home-oranjestad-6',
#  'https://homecityaruba.com//listings/hooiberg-63',
#  'https://homecityaruba.com//listings/madiki-52-h',
#  'https://homecityaruba.com//listings/paramira-47',
#  'https://homecityaruba.com//listings/paramira-84',
#  'https://homecityaruba.com//listings/home-savaneta-3',
#  'https://homecityaruba.com//listings/home-savaneta-2',
#  'https://homecityaruba.com//listings/home-tanki-leendert-2',
#  'https://homecityaruba.com//listings/land-bubali-solarium-lot-7-8',
#  'https://homecityaruba.com//listings/fixer-upper-pos-chiquito',
#  'https://homecityaruba.com//listings/wariruri-condos',
#  'https://homecityaruba.com//listings/wayaca-residence',
#  'https://homecityaruba.com//listings/papaya',
#  'https://homecityaruba.com//listings/home-picaron',
#  'https://homecityaruba.com//listings/home-seroe-biento',
#  'https://homecityaruba.com//listings/offices-oranjestad',
#  'https://homecityaruba.com//listings/montana-plaza-233',
#  'https://homecityaruba.com//listings/paseodeplaya',
#  'https://homecityaruba.com//listings/rooikochi62G',
#  'https://homecityaruba.com//listings/villa-paraiso-2',
#  'https://homecityaruba.com//listings/andicuri-condos',
#  'https://homecityaruba.com//listings/sabana-abao',
#  'https://homecityaruba.com//listings/townhouse-napa-valley',
#  'https://homecityaruba.com//listings/home-ponton-3',
#  'https://homecityaruba.com//listings/home-tanki-leendert-5',
#  'https://homecityaruba.com//listings/home-papilon',
#  'https://homecityaruba.com//listings/tanki-leendert-135-h',
#  'https://homecityaruba.com//listings/home-tanki-leendert-3',
#  'https://homecityaruba.com//listings/Noord104D',
#  'https://homecityaruba.com//listings/home-noord',
#  'https://homecityaruba.com//listings/home-picaron-2',
#  'https://homecityaruba.com//listings/savaneta-3156-m2',
#  'https://homecityaruba.com//listings/home-pos-chikito-2',
#  'https://homecityaruba.com//listings/home-nune',
#  'https://homecityaruba.com//listings/santa-cruz-10000-m2',
#  'https://homecityaruba.com//listings/home-paradera-2',
#  'https://homecityaruba.com//listings/apartment-complex-wayaca',
#  'https://homecityaruba.com//listings/san-nicolas-5949-m2',
#  'https://homecityaruba.com//listings/seroe-preto-29',
#  'https://homecityaruba.com//listings/apartment-complex-in-noord',
#  'https://homecityaruba.com//listings/home-moko',
#  'https://homecityaruba.com//listings/land-tierra-del-sol',
#  'https://homecityaruba.com//listings/commercial-building-oranjestad-4',
#  'https://homecityaruba.com//listings/piedra-plat-78-b',
#  'https://homecityaruba.com//listings/home-cumana',
#  'https://homecityaruba.com//listings/commercial-building-oranjestad-3',
#  'https://homecityaruba.com//listings/villa-papilon',
#  'https://homecityaruba.com//listings/oranjestad-882-m2',
#  'https://homecityaruba.com//listings/home-casibari78',
#  'https://homecityaruba.com//listings/wayaca-residence-365',
#  'https://homecityaruba.com//listings/family-home-san-barbola',
#  'https://homecityaruba.com//listings/home-san-barbola-206',
#  'https://homecityaruba.com//listings/condo-oranjestad-2',
#  'https://homecityaruba.com//listings/pearl-condo',
#  'https://homecityaruba.com//listings/divi-condo',
#  'https://homecityaruba.com//listings/blue-residences-623',
#  'https://homecityaruba.com//listings/palmaruba-417',
#  'https://homecityaruba.com//listings/home-99-gold-coast',
#  'https://homecityaruba.com//listings/bubali-73-g',
#  'https://homecityaruba.com//listings/tuscany-condo',
#  'https://homecityaruba.com//listings/home-bubali-6',
#  'https://homecityaruba.com//listings/home-moko-3',
#  'https://homecityaruba.com//listings/Bushistraat1',
#  'https://homecityaruba.com//listings/condo-tierra-del-sol',
#  'https://homecityaruba.com//listings/home-boroncana-2',
#  'https://homecityaruba.com//listings/villa-morgenster',
#  'https://homecityaruba.com//listings/ponton-123-b',
#  'https://homecityaruba.com//listings/villa-sale-gold-coast-residences',
#  'https://homecityaruba.com//listings/diamante-155',
#  'https://homecityaruba.com//listings/cove-106',
#  'https://homecityaruba.com//listings/mainstreet-63',
#  'https://homecityaruba.com//listings/caya-betico-croes-134',
#  'https://homecityaruba.com//listings/apartment-complex-oranjestad',
#  'https://homecityaruba.com//listings/home-rooi-kochi',
#  'https://homecityaruba.com//listings/apartment-complex-sabana-blanco-airport',
#  'https://homecityaruba.com//listings/blue-residences-312',
#  'https://homecityaruba.com//listings/daimari-watervillas',
#  'https://homecityaruba.com//listings/seroe-blanco-5585-m2',
#  'https://homecityaruba.com//listings/villa-babijn',
#  'https://homecityaruba.com//listings/portside-building',
#  'https://homecityaruba.com//listings/home-palm-beach-4',
#  'https://homecityaruba.com//listings/commercial-building-oranjestad',
#  'https://homecityaruba.com//listings/zoutmanstraat-5',
#  'https://homecityaruba.com//listings/commercial-building-oranjestad-5',
#  'https://homecityaruba.com//listings/porta-al-sole',
#  'https://homecityaruba.com//listings/cove-108',
#  'https://homecityaruba.com//listings/villa-boroncana',
#  'https://homecityaruba.com//listings/acqua-condominiums',
#  'https://homecityaruba.com//listings/sombre-6974-m2',
#  'https://homecityaruba.com//listings/sombre-22',
#  'https://homecityaruba.com//listings/gold-coast-diamante-148',
#  'https://homecityaruba.com//listings/villa-pool-morgenster',
#  'https://homecityaruba.com//listings/home-oranjestad-4',
#  'https://homecityaruba.com//listings/bar-restaurant-apt-sale',
#  'https://homecityaruba.com//listings/home-bakvak',
#  'https://homecityaruba.com//listings/home-at-bubali',
#  'https://homecityaruba.com//listings/home-palm-beach',
#  'https://homecityaruba.com//listings/ocean-front-condo-groundfloor',
#  'https://homecityaruba.com//listings/blue-residences-aquamarine-tower-221',
#  'https://homecityaruba.com//listings/solarium-suites-14',
#  'https://homecityaruba.com//listings/mainstreet-74',
#  'https://homecityaruba.com//listings/gold-coast-villa',
#  'https://homecityaruba.com//listings/coral-shell-gf-b',
#  'https://homecityaruba.com//listings/anabui-residence-2',
#  'https://homecityaruba.com//listings/condo-le-vent',
#  'https://homecityaruba.com//listings/anabui-residence-5',
#  'https://homecityaruba.com//listings/atlantic-residences',
#  'https://homecityaruba.com//listings/villa-gold-coast-3',
#  'https://homecityaruba.com//listings/mainstreet-42-46',
#  'https://homecityaruba.com//listings/palmitastraat-5',
#  'https://homecityaruba.com//listings/home-tierra-del-sol-4',
#  'https://homecityaruba.com//listings/home-tunastraat',
#  'https://homecityaruba.com//listings/oceana-condo-ground-floor',
#  'https://homecityaruba.com//listings/opal-133',
#  'https://homecityaruba.com//listings/ocean-front-indigo-penthouse',
#  'https://homecityaruba.com//listings/malmokweg-32',
#  'https://homecityaruba.com//listings/blue-residences-indigo-tower-ph-1-2',
#  'https://homecityaruba.com//listings/building-oranjestad-3',
#  'https://homecityaruba.com//listings/commercial-building-eagle',
#  'https://homecityaruba.com//listings/kudawecha-40',
#  'https://homecityaruba.com//listings/home-opal',
#  'https://homecityaruba.com//listings/ocean-front-penthouse',
#  'https://homecityaruba.com//listings/savaneta-11800-m2',
#  'https://homecityaruba.com//listings/villa-hill-morgenster',
#  'https://homecityaruba.com//listings/home-opal-2',
#  'https://homecityaruba.com//listings/frankrijkstraat-7',
#  'https://homecityaruba.com//listings/building-oranjestad-2',
#  'https://homecityaruba.com//listings/lg-smith-boulevard',
#  'https://homecityaruba.com//listings/villa-tierra-del-sol-4',
#  'https://homecityaruba.com//listings/lg-smith-boulevard-529',
#  'https://homecityaruba.com//listings/eagle-beach-5000m2-property-land',
#  'https://homecityaruba.com//listings/condo-ocean-z',
#  'https://homecityaruba.com//listings/commercial-building-oranjestad-2',
#  'https://homecityaruba.com//listings/villa-gold-coast-4',
#  'https://homecityaruba.com//listings/tanki-leendert4E',
#  'https://homecityaruba.com//listings/studio-tanki-leendert',
#  'https://homecityaruba.com//listings/apartment-ponton',
#  'https://homecityaruba.com//listings/studio-piedra-plat',
#  'https://homecityaruba.com//listings/studio-noord',
#  'https://homecityaruba.com//listings/studio-regents-park-residence',
#  'https://homecityaruba.com//listings/appartment-santa-cruz',
#  'https://homecityaruba.com//listings/appartment-in-madiki',
#  'https://homecityaruba.com//listings/apartment-seroe-blanco',
#  'https://homecityaruba.com//listings/apartment-palm-beach',
#  'https://homecityaruba.com//listings/one-bedroom-apartment-regents-park-residence',
#  'https://homecityaruba.com//listings/irenestraat-2-bedroom-aprtment',
#  'https://homecityaruba.com//listings/rutena-3',
#  'https://homecityaruba.com//listings/rutena-2',
#  'https://homecityaruba.com//listings/apartment-noord',
#  'https://homecityaruba.com//listings/cunucu-house-babijn',
#  'https://homecityaruba.com//listings/appartment-in-madiki-2',
#  'https://homecityaruba.com//listings/apartment',
#  'https://homecityaruba.com//listings/apartment-wayaca',
#  'https://homecityaruba.com//listings/apartment-paradera',
#  'https://homecityaruba.com//listings/apt-catiri',
#  'https://homecityaruba.com//listings/2-bedroom-home-regents-park-residence-4',
#  'https://homecityaruba.com//listings/2-bedroom-home-regents-park-residence-5',
#  'https://homecityaruba.com//listings/palm-beach-rental',
#  'https://homecityaruba.com//listings/commercial-units',
#  'https://homecityaruba.com//listings/home-madiki',
#  'https://homecityaruba.com//listings/apartment-noord-2',
#  'https://homecityaruba.com//listings/2-bedroom-apt-palm-beach',
#  'https://homecityaruba.com//listings/commercial-building-san-nicolas',
#  'https://homecityaruba.com//listings/commercial-building-ponton',
#  'https://homecityaruba.com//listings/home-pos-chiquito-2',
#  'https://homecityaruba.com//listings/home-pos-chiquito-3',
#  'https://homecityaruba.com//listings/retail-building-oranjestad-2',
#  'https://homecityaruba.com//listings/house-bubali',
#  'https://homecityaruba.com//listings/piedra-plat-98-paradera',
#  'https://homecityaruba.com//listings/napa-valley-home',
#  'https://homecityaruba.com//listings/home-paradera',
#  'https://homecityaruba.com//listings/home-esmeralda',
#  'https://homecityaruba.com//listings/2-bedroom-apartment-regents-park-residence',
#  'https://homecityaruba.com//listings/alto-prado-unit-8',
#  'https://homecityaruba.com//listings/apartment-2',
#  'https://homecityaruba.com//listings/home-bubali',
#  'https://homecityaruba.com//listings/duplex-home-noord',
#  'https://homecityaruba.com//listings/home-ponton-2',
#  'https://homecityaruba.com//listings/home-calbas-25',
#  'https://homecityaruba.com//listings/cozy-house-sabana-basora',
#  'https://homecityaruba.com//listings/home-primavera',
#  'https://homecityaruba.com//listings/commercial-location-eagle',
#  'https://homecityaruba.com//listings/home-wayaca',
#  'https://homecityaruba.com//listings/home-seroe-blanco',
#  'https://homecityaruba.com//listings/home-bona-vista',
#  'https://homecityaruba.com//listings/commercial-location-oranjestad',
#  'https://homecityaruba.com//listings/commercial-unit',
#  'https://homecityaruba.com//listings/apartment-3',
#  'https://homecityaruba.com//listings/nune-7f',
#  'https://homecityaruba.com//listings/house-papilon',
#  'https://homecityaruba.com//listings/ponton90D',
#  'https://homecityaruba.com//listings/home-tanki-leendert-4',
#  'https://homecityaruba.com//listings/commercial-unit-piedra-plat-2',
#  'https://homecityaruba.com//listings/diamante-139-b',
#  'https://homecityaruba.com//listings/officeretail-space-solito-oranjestad',
#  'https://homecityaruba.com//listings/wayaca-43-g',
#  'https://homecityaruba.com//listings/commercial-unit-piedra-plat-3',
#  'https://homecityaruba.com//listings/home-piedra-plat',
#  'https://homecityaruba.com//listings/las-rocas-17-c',
#  'https://homecityaruba.com//listings/luxury-2-bedroom-apartment-solito',
#  'https://homecityaruba.com//listings/office-space-oranjestad',
#  'https://homecityaruba.com//listings/villa-noord',
#  'https://homecityaruba.com//listings/apartment-tierra-del-sol-2',
#  'https://homecityaruba.com//listings/luxury-3-bedroom-apartment-solito-oranjestad-noord',
#  'https://homecityaruba.com//listings/cas-di-zoe',
#  'https://homecityaruba.com//listings/tibushi-2',
#  'https://homecityaruba.com//listings/opal-133-2',
#  'https://homecityaruba.com//listings/anabui-residence-2-2',
#  'https://homecityaruba.com//listings/warehouse-pos-chiquito',
#  'https://homecityaruba.com//listings/offices-pos-chiquito',
#  'https://homecityaruba.com//listings/office-building-eagle-area']

# %%
def get_details(urls):
    property_list = []
    for link in urls:
        req = requests.get(link)
        soup = BeautifulSoup(req.content, 'html.parser')
        dom = etree.HTML(str(soup))
        
        name = soup.find('h1', class_ = 'heading__inner').text.strip().split("-")[0]
            #location = soup.find(lambda t: t.name == 'dt' and 'District' in t.text).findNext('dd').string
        property_status = soup.find('div', class_ = 'content').text.split(' ')[0]
        price= soup.find('h1', class_ = 'heading__inner').text.strip().split("-")[1].strip()
        try:    
            bathroom = soup.find('div', class_ = 'property-info__inner container').find_all('li', class_ = 'amenities-items__item')[1].text.split(':')[1]
            rooms =  soup.find('div', class_ = 'property-info__inner container').find_all('li', class_ = 'amenities-items__item')[2].text.split(':')[1]
        except IndexError:
            bathroom = None
            rooms = None
        
            
        prop = {
            'name': name,
            'location': None,
            'property': property_status,
            'price': price,
            'bedrooms': rooms,
            'bathrooms' : bathroom,
            'Pool':None,
            'link': link
        }
        property_list.append(prop)
        print('Saving:', prop['name'])
        
    df = pd.DataFrame(property_list)
    print(df.head(20))
    df.to_csv('homecity.csv', header=True, index=False)

# %%
get_details(path2)
# Out:
# Saving: Bubali 225 m2
# Saving: Noord 392 m2
# Saving: Modanza 470 m2
# Saving: Bubali Solarium Lot 8
# Saving: Bubali Solarium lot 7
# Saving: Sabana Blanco Lot 4 (1203m2)
# Saving: Sabana Blanco Lot 3 (1203m2)
# Saving: Tazajal 9
# Saving: Seroe Blanco 438 m2
# Saving: Home and land at Santa Cruz
# Saving: Home at Sabana Basora
# Saving: Tazajal 15
# Saving: Bubali Solarium Residence 11
# Saving: Home at Pos Chiquito
# Saving: Apartment in Oranjestad
# Saving: Home at Oranjestad
# Saving: Home at Hooiberg
# Saving: Home at Madiki
# Saving: Paramira 47
# Saving: Paramira 84
# Saving: Home at Savaneta
# Saving: Home at Savaneta
# Saving: Isla Esmeralda
# Saving: Solarium lot 7 & 8
# Saving: Fixer Upper in Pos Chiquito
# Saving: Wariruri Condos
# Saving: Home at Wayaca Residence
# Saving: Home at Papaya
# Saving: Home at Picaron
# Saving: Home at Seroe Biento
# Saving: Offices in Oranjestad
# Saving: Montaña Plaza 233
# Saving: Paseo de Playa (TDS) 659 m2
# Saving: House at Rooi Kochi
# Saving: Villa Paraiso
# Saving: Andicuri condos
# Saving: Home at Sabana Blanco
# Saving: Townhouse in Napa Valley
# Saving: Home at Ponton
# Saving: Home at Tanki Leendert
# Saving: Home at Papilon
# Saving: Home at Tanki Leendert
# Saving: Home at Tanki Leendert
# Saving: Home in Noord
# Saving: Home at Noord
# Saving: Home at Picaron
# Saving: Savaneta 3156 m2
# Saving: Home at Pos Chikito
# Saving: Home in Nuñe
# Saving: Santa Cruz 10.000 m2
# Saving: Home at Paradera
# Saving: Apartment Complex at Wayaca
# Saving: San Nicolas 5949 m2
# Saving: Home at Seroe Preto
# Saving: Apartment Complex in Noord
# Saving: Home at Moko Residence
# Saving: Catalina Estates (TDS) 747 m2
# Saving: Commercial building in Oranjestad
# Saving: Home at Piedra Plat
# Saving: Home at Cumana
# Saving: Commercial building in Oranjestad
# Saving: Villa in Papilon
# Saving: Oranjestad 882 m2
# Saving: Home in Casibari
# Saving: Home at Wayaca Residence
# Saving: Family home in San Barbola
# Saving: Family Home in San Barbola
# Saving: Condo in Oranjestad
# Saving: Pearl condos
# Saving: Divi Condo
# Saving: Condo at Blue Residences
# Saving: Condo at Palmaruba
# Saving: Gold Coast 99
# Saving: Home at Bubali
# Saving: Arashi Boutique Condo
# Saving: Home at Bubali
# Saving: Moko Residence 157
# Saving: Home at Ponton
# Saving: Condo in Tierra del Sol
# Saving: Home at Boroncana
# Saving: Villa Morgenster 5
# Saving: Home at Ponton
# Saving: Gold Coast 157
# Saving: Gold Coast
# Saving: The Cove 106
# Saving: Building in Mainstreet
# Saving: Home in Oranjestad
# Saving: Apartment Complex in Oranjestad
# Saving: Home at Rooi Kochi
# Saving: Apartment complex at Sabana Blanco
# Saving: Blue Residences 312
# Saving: Daimari Watervillas
# Saving: Seroe Blanco 5585 m2
# Saving: Home at Babijn
# Saving: Portside building in Oranjestad
# Saving: Home at Palm Beach
# Saving: Building in Oranjestad
# Saving: Building in Zoutmanstraat
# Saving: Warehouse in Oranjestad
# Saving: Porta al Sole
# Saving: The Cove 109
# Saving: Villa Boroncana
# Saving: Acqua Condominiums
# Saving: Sombre 6974 m2
# Saving: Sombre 22
# Saving: Gold Coast 148
# Saving: Villa Morgenster 13
# Saving: Home at Oranjestad
# Saving: Famous Motin Horeca Complex
# Saving: Home at Bakval
# Saving: Home at Bubali
# Saving: Home at Palm Beach
# Saving: Ocean front condo on the ground floor
# Saving: Blue Residences 221
# Saving: Solarium Suites complex
# Saving: Commercial building in Mainstreet
# Saving: Gold Coast 142
# Saving: Coral Shell GF
# Saving: Anabui Residence # 2
# Saving: Condo at Le Vent 108
# Saving: Anabui Residence # 5
# Saving: Atlantic Residences
# Saving: Gold Coast 177
# Saving: Commercial building in Mainstreet
# Saving: Home at Ponton
# Saving: Home at Tierra del Sol
# Saving: Home in Ponton
# Saving: Condo at Oceania Residences
# Saving: Home at Opal
# Saving: Ocean front Indigo Penthouse 1
# Saving: Home at Malmokweg
# Saving: Blue Residences PH 1
# Saving: Building in Oranjestad
# Saving: Commercial building in Eagle
# Saving: Kudawecha 40
# Saving: Home at Opal
# Saving: Ocean Front Turquiose Penthouse
# Saving: Commercial Property in Savaneta 11.800 m2
# Saving: Villa Morgenster 11
# Saving: Home at Opal
# Saving: Commercial building at Eagle
# Saving: Building with apartments in Oranjestad
# Saving: Home at Malmok Beach
# Saving: Casa Versace at Tierra del Sol
# Saving: Home at Malmok Beach
# Saving: Eagle Beach 5000m2 Property land
# Saving: Boutique Hotel at Malmok
# Saving: Commercial building in Oranjestad
# Saving: Lemon Stream Properties www.lemonstreamproperties.com
# Saving: Tanki Leendert Studio
# Saving: Studio at Tanki Leendert
# Saving: Apartment in Ponton
# Saving: Studio at Piedra Plat
# Saving: Studio in Noord
# Saving: Studio Regents Park no. 3
# Saving: Appartment in Santa Cruz
# Saving: Appartment in Madiki
# Saving: Apartment in Seroe Blanco
# Saving: Apartment in Palm Beach
# Saving: One
# Saving: Apartment in Oranjestad
# Saving: Rutena Oranjestad #2
# Saving: Rutena Oranjestad #1
# Saving: Noord Apt. #2A
# Saving: Cunucu house in Babijn
# Saving: Appartment in Madiki
# Saving: Apartment in Ponton
# Saving: Apartment in Wayaca
# Saving: Apartment in Paradera
# Saving: Apartment in Catiri
# Saving: Two
# Saving: Two
# Saving: Condo at Palm Beach
# Saving: Offices at Tanki Flip
# Saving: Home at Madiki
# Saving: Apartment in Noord
# Saving: Apartment at Palm Beach
# Saving: Commercial building in San Nicolas
# Saving: Commercial building in Ponton
# Saving: Home at Pos Chiquito
# Saving: Home at Pos Chiquito
# Saving: Commercial Building Oranjestad
# Saving: House in Bubali
# Saving: Offices at Piedra Plat
# Saving: Napa Valley home
# Saving: Home at Paradera
# Saving: Home at Esmeralda
# Saving: Two
# Saving: Alto Prado Unit 8
# Saving: Apartment in Palm Beach
# Saving: Home at Bubali
# Saving: Duplex Home in Noord
# Saving: Home at Ponton
# Saving: Home at Calbas
# Saving: Cozy House in Sabana Basora
# Saving: Home at Primavera
# Saving: Commercial location in Eagle
# Saving: Home at Wayaca
# Saving: Home at Seroe Blanco
# Saving: Home at Bona Vista
# Saving: Bayside Mall in Oranjestad
# Saving: Commercial Unit in Piedra Plat 1
# Saving: Apartment in Palm Beach
# Saving: House in Nune
# Saving: House in Papilon
# Saving: Home at Ponton
# Saving: Home at Tanki Leendert
# Saving: commercial unit in piedra plat 2
# Saving: Gold Coast 139B
# Saving: Commercial space in Oranjestad
# Saving: Building in Wayaca
# Saving: Commercial unit Piedra Plat 3
# Saving: Home at Piedra Plat
# Saving: Las Rocas 17
# Saving: Two bedroom apartment in Oranjestad
# Saving: Office space in Oranjestad
# Saving: Villa in Noord
# Saving: Condo at Tierra del Sol
# Saving: 3 bedroom apartment in Oranjestad
# Saving: Cas Di Zoe
# Saving: Home at Tibushi
# Saving: Home at Opal
# Saving: Anabui Residence # 2
# Saving: Warehouse Pos Chiquito
# Saving: Offices Pos Chiquito
# Saving: Office building in Eagle Area
#                              name location            property        price  \
# 0                  Bubali 225 m2      None               \n!ON   USD 59,000
# 1                   Noord 392 m2      None      \nSold!\nGreat   USD 60,000
# 2                 Modanza 470 m2      None      \nSold!\nGreat   USD 83,650
# 3          Bubali Solarium Lot 8      None               \nLot   USD 93,800
# 4          Bubali Solarium lot 7      None               \nLot  USD 100,240
# 5   Sabana Blanco Lot 4 (1203m2)      None         \nPerfectly  USD 104,000
# 6   Sabana Blanco Lot 3 (1203m2)      None         \nPerfectly  USD 104,000
# 7                      Tazajal 9      None    \nSold!\nTazajal  USD 110,000
# 8            Seroe Blanco 438 m2      None           \nPerfect  USD 112,360
# 9    Home and land at Santa Cruz      None  \nSold!\nAuthentic  USD 120,000
# 10         Home at Sabana Basora      None              \nCozy  USD 124,857
# 11                    Tazajal 15      None           \nTazajal  USD 125,000
# 12  Bubali Solarium Residence 11      None               \nLot  USD 129,000
# 13          Home at Pos Chiquito      None         \nMOTIVATED  USD 134,000
# 14       Apartment in Oranjestad      None             \n COZY  USD 135,000
# 15            Home at Oranjestad      None              \nCozy  USD 135,000
# 16              Home at Hooiberg      None       \nSold!\nThis  USD 140,000
# 17                Home at Madiki      None       \nSold!\nThis  USD 157,000
# 18                   Paramira 47      None      \nSold!\nGreat  USD 175,000
# 19                   Paramira 84      None      \nSold!\nGreat  USD 175,000
#
#              bedrooms  bathrooms  Pool  \
# 0                None       None  None
# 1                None       None  None
# 2                None       None  None
# 3                None       None  None
# 4                None       None  None
# 5    Walking Distance   1.203 m2  None
# 6         Short Drive   1.203 m2  None
# 7                   2          2  None
# 8                None       None  None
# 9              202 m2     635 m2  None
# 10             115 m2     207 m2  None
# 11                  2          2  None
# 12        Short Drive     461 m2  None
# 13             222 m2     360 m2  None
# 14              68 m2      70 m2  None
# 15              99 m2     144 m2  None
# 16             101 m2     801 m2  None
# 17             121 m2     641 m2  None
# 18                  3     323 m2  None
# 19                  4     316 m2  None
#
#                                                  link
# 0   https://homecityaruba.com//listings/land-bubali-3
# 1    https://homecityaruba.com//listings/noord-392-m2
# 2   https://homecityaruba.com//listings/modanza-47...
# 3   https://homecityaruba.com//listings/land-bubal...
# 4   https://homecityaruba.com//listings/land-bubal...
# 5   https://homecityaruba.com//listings/sabana-bla...
# 6   https://homecityaruba.com//listings/sabana-bla...
# 7    https://homecityaruba.com//listings/home-tazajal
# 8   https://homecityaruba.com//listings/seroe-blan...
# 9   https://homecityaruba.com//listings/house-sta-...
# 10  https://homecityaruba.com//listings/cozy-saban...
# 11     https://homecityaruba.com//listings/tazajal-15
# 12  https://homecityaruba.com//listings/land-bubal...
# 13  https://homecityaruba.com//listings/home-pos-c...
# 14  https://homecityaruba.com//listings/apartment-...
# 15  https://homecityaruba.com//listings/home-oranj...
# 16    https://homecityaruba.com//listings/hooiberg-63
# 17    https://homecityaruba.com//listings/madiki-52-h
# 18    https://homecityaruba.com//listings/paramira-47
# 19    https://homecityaruba.com//listings/paramira-84
